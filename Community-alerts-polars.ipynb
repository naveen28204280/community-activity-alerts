# %%
import requests
#import pandas as pd
import matplotlib.pyplot as plt
import polars as pl

# %%
# Convert edit_counts to a Polars DataFrame
def generate_dataframe(edit_counts):
    df = pl.DataFrame(edit_counts)
    df = df.with_columns(pl.col("timestamp").str.strptime(pl.Datetime, format="%Y-%m-%dT%H:%M:%S.%fZ"))
    print(df)
    return df

# %%
def find_peaks_rolling_3_years(df, threshold_percentage=0.30):
    rolling_means = []
    thresholds = []
    differences = []
    peaks = []

    for i in range(df.height):  # Iterate over rows
        current_timestamp = df[i, "timestamp"]

        # Get data within the last 3 years
        past_3_years_data = df.filter(
            (pl.col("timestamp") <= current_timestamp) &
            (pl.col("timestamp") >= current_timestamp - pl.duration(days=365*3))
        )

        # Calculate the rolling mean for the past 3 years
        rolling_mean = past_3_years_data["edits"].mean()
        rolling_means.append(rolling_mean)
        
        # Calculate the threshold
        threshold_value = rolling_mean * (1 + threshold_percentage / 100)
        thresholds.append(threshold_value)
        
        # Calculate the difference
        difference = df["edits"][i] - threshold_value
        differences.append(difference)
        
        # Identify peaks
        if df["edits"][i] > threshold_value:
            peaks.append(i)
    
    # Add new columns to the DataFrame
    df = df.with_columns(
        pl.Series(rolling_means).alias("rolling_mean"),
        pl.Series(thresholds).alias("threshold"),
        pl.Series(differences).alias("difference")
    )
    
    return peaks, df

# %%
def log_peaks(peaks, df):
    for peak_index in peaks:
        print(f"Peak Index: {peak_index}")
        print(f"Timestamp: {df['timestamp'][peak_index]}")
        print(f"Edits: {df['edits'][peak_index]}")
        print(f"Rolling Mean: {df['rolling_mean'][peak_index]:.2f}")
        print(f"Threshold: {df['threshold'][peak_index]:.2f}")
        print(f"Difference: {df['difference'][peak_index]:.2f}\n")

# %%
base_url = "https://wikimedia.org/api/rest_v1/metrics/edits/aggregate"

project = "uz.wikipedia.org"      
editor_type = "all-editor-types"  
page_type = "all-page-types"      
granularity = "monthly"           
start = "20140101"                
end = "20240101"  

rolling_window = 3
# Set the threshold percentage (30%)
threshold_percentage = 30


url = f"{base_url}/{project}/{editor_type}/{page_type}/{granularity}/{start}/{end}"

response = requests.get(url)


if response.status_code == 200:
    data = response.json()
    #print("Number of edits data:")
    #print(data)
else:
    print(f"Error: {response.status_code} - {response.text}")
    
    
edit_counts=data["items"][0]["results"]

df = generate_dataframe(edit_counts)
peaks,df = find_peaks_rolling_3_years(df, threshold_percentage)
log_peaks(peaks,df)
# Out:
# shape: (120, 2)
# ┌─────────────────────┬───────┐
# │ timestamp           ┆ edits │
# │ ---                 ┆ ---   │
# │ datetime[μs]        ┆ i64   │
# ╞═════════════════════╪═══════╡
# │ 2014-01-01 00:00:00 ┆ 2308  │
# │ 2014-02-01 00:00:00 ┆ 2505  │
# │ 2014-03-01 00:00:00 ┆ 2216  │
# │ 2014-04-01 00:00:00 ┆ 6288  │
# │ 2014-05-01 00:00:00 ┆ 5368  │
# │ …                   ┆ …     │
# │ 2023-08-01 00:00:00 ┆ 33798 │
# │ 2023-09-01 00:00:00 ┆ 40689 │
# │ 2023-10-01 00:00:00 ┆ 23974 │
# │ 2023-11-01 00:00:00 ┆ 40802 │
# │ 2023-12-01 00:00:00 ┆ 20211 │
# └─────────────────────┴───────┘
# Peak Index: 3
# Timestamp: 2014-04-01 00:00:00
# Edits: 6288
# Rolling Mean: 3329.25
# Threshold: 4328.03
# Difference: 1959.97
#
# Peak Index: 4
# Timestamp: 2014-05-01 00:00:00
# Edits: 5368
# Rolling Mean: 3737.00
# Threshold: 4858.10
# Difference: 509.90
#
# Peak Index: 11
# Timestamp: 2014-12-01 00:00:00
# Edits: 8661
# Rolling Mean: 3445.00
# Threshold: 4478.50
# Difference: 4182.50
#
# Peak Index: 12
# Timestamp: 2015-01-01 00:00:00
# Edits: 13979
# Rolling Mean: 4255.31
# Threshold: 5531.90
# Difference: 8447.10
#
# Peak Index: 13
# Timestamp: 2015-02-01 00:00:00
# Edits: 6269
# Rolling Mean: 4399.14
# Threshold: 5718.89
# Difference: 550.11
#
# Peak Index: 14
# Timestamp: 2015-03-01 00:00:00
# Edits: 9001
# Rolling Mean: 4705.93
# Threshold: 6117.71
# Difference: 2883.29
#
# Peak Index: 19
# Timestamp: 2015-08-01 00:00:00
# Edits: 39533
# Rolling Mean: 6039.20
# Threshold: 7850.96
# Difference: 31682.04
#
# Peak Index: 20
# Timestamp: 2015-09-01 00:00:00
# Edits: 70141
# Rolling Mean: 9091.67
# Threshold: 11819.17
# Difference: 58321.83
#
# Peak Index: 22
# Timestamp: 2015-11-01 00:00:00
# Edits: 28937
# Rolling Mean: 9645.26
# Threshold: 12538.84
# Difference: 16398.16
#
# Peak Index: 23
# Timestamp: 2015-12-01 00:00:00
# Edits: 38048
# Rolling Mean: 10828.71
# Threshold: 14077.32
# Difference: 23970.68
#
# Peak Index: 55
# Timestamp: 2018-08-01 00:00:00
# Edits: 20939
# Rolling Mean: 6554.75
# Threshold: 8521.18
# Difference: 12417.82
#
# Peak Index: 56
# Timestamp: 2018-09-01 00:00:00
# Edits: 8074
# Rolling Mean: 4830.67
# Threshold: 6279.87
# Difference: 1794.13
#
# Peak Index: 68
# Timestamp: 2019-09-01 00:00:00
# Edits: 8080
# Rolling Mean: 3136.03
# Threshold: 4076.84
# Difference: 4003.16
#
# Peak Index: 69
# Timestamp: 2019-10-01 00:00:00
# Edits: 4901
# Rolling Mean: 3240.05
# Threshold: 4212.07
# Difference: 688.93
#
# Peak Index: 74
# Timestamp: 2020-03-01 00:00:00
# Edits: 6067
# Rolling Mean: 3662.56
# Threshold: 4761.32
# Difference: 1305.68
#
# Peak Index: 75
# Timestamp: 2020-04-01 00:00:00
# Edits: 7069
# Rolling Mean: 3823.08
# Threshold: 4970.01
# Difference: 2098.99
#
# Peak Index: 79
# Timestamp: 2020-08-01 00:00:00
# Edits: 6530
# Rolling Mean: 4312.89
# Threshold: 5606.76
# Difference: 923.24
#
# Peak Index: 80
# Timestamp: 2020-09-01 00:00:00
# Edits: 6662
# Rolling Mean: 4354.64
# Threshold: 5661.03
# Difference: 1000.97
#
# Peak Index: 81
# Timestamp: 2020-10-01 00:00:00
# Edits: 6757
# Rolling Mean: 4442.11
# Threshold: 5774.74
# Difference: 982.26
#
# Peak Index: 83
# Timestamp: 2020-12-01 00:00:00
# Edits: 8499
# Rolling Mean: 4650.50
# Threshold: 6045.65
# Difference: 2453.35
#
# Peak Index: 84
# Timestamp: 2021-01-01 00:00:00
# Edits: 13667
# Rolling Mean: 4983.56
# Threshold: 6478.62
# Difference: 7188.38
#
# Peak Index: 85
# Timestamp: 2021-02-01 00:00:00
# Edits: 7157
# Rolling Mean: 5059.00
# Threshold: 6576.70
# Difference: 580.30
#
# Peak Index: 90
# Timestamp: 2021-07-01 00:00:00
# Edits: 9331
# Rolling Mean: 5241.72
# Threshold: 6814.24
# Difference: 2516.76
#
# Peak Index: 91
# Timestamp: 2021-08-01 00:00:00
# Edits: 16587
# Rolling Mean: 5120.83
# Threshold: 6657.08
# Difference: 9929.92
#
# Peak Index: 92
# Timestamp: 2021-09-01 00:00:00
# Edits: 67248
# Rolling Mean: 6764.56
# Threshold: 8793.92
# Difference: 58454.08
#
# Peak Index: 93
# Timestamp: 2021-10-01 00:00:00
# Edits: 60429
# Rolling Mean: 8379.33
# Threshold: 10893.13
# Difference: 49535.87
#
# Peak Index: 94
# Timestamp: 2021-11-01 00:00:00
# Edits: 34702
# Rolling Mean: 9284.83
# Threshold: 12070.28
# Difference: 22631.72
#
# Peak Index: 95
# Timestamp: 2021-12-01 00:00:00
# Edits: 52707
# Rolling Mean: 10695.97
# Threshold: 13904.76
# Difference: 38802.24
#
# Peak Index: 96
# Timestamp: 2022-01-01 00:00:00
# Edits: 31705
# Rolling Mean: 11475.81
# Threshold: 14918.55
# Difference: 16786.45
#
# Peak Index: 97
# Timestamp: 2022-02-01 00:00:00
# Edits: 23775
# Rolling Mean: 12066.03
# Threshold: 15685.84
# Difference: 8089.16
#
# Peak Index: 100
# Timestamp: 2022-05-01 00:00:00
# Edits: 65788
# Rolling Mean: 14116.72
# Threshold: 18351.74
# Difference: 47436.26
#
# Peak Index: 101
# Timestamp: 2022-06-01 00:00:00
# Edits: 67272
# Rolling Mean: 15939.69
# Threshold: 20721.60
# Difference: 46550.40
#
# Peak Index: 102
# Timestamp: 2022-07-01 00:00:00
# Edits: 41714
# Rolling Mean: 17053.50
# Threshold: 22169.55
# Difference: 19544.45
#
# Peak Index: 103
# Timestamp: 2022-08-01 00:00:00
# Edits: 81201
# Rolling Mean: 19232.83
# Threshold: 25002.68
# Difference: 56198.32
#
# Peak Index: 104
# Timestamp: 2022-09-01 00:00:00
# Edits: 100622
# Rolling Mean: 21803.44
# Threshold: 28344.48
# Difference: 72277.52
#
# Peak Index: 105
# Timestamp: 2022-10-01 00:00:00
# Edits: 186568
# Rolling Mean: 26849.75
# Threshold: 34904.68
# Difference: 151663.33
#
# Peak Index: 106
# Timestamp: 2022-11-01 00:00:00
# Edits: 222754
# Rolling Mean: 32945.06
# Threshold: 42828.57
# Difference: 179925.43
#
# Peak Index: 107
# Timestamp: 2022-12-01 00:00:00
# Edits: 132806
# Rolling Mean: 36517.94
# Threshold: 47473.33
# Difference: 85332.67
# C:\Users\HP\AppData\Local\Temp\ipykernel_27496\1643222482.py:4: ChronoFormatWarning: Detected the pattern `.%f` in the chrono format string. This pattern should not be used to parse values after a decimal point. Use `%.f` instead. See the full specification: https://docs.rs/chrono/latest/chrono/format/strftime
#   df = df.with_columns(pl.col("timestamp").str.strptime(pl.Datetime, format="%Y-%m-%dT%H:%M:%S.%fZ"))
